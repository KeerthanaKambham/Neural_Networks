# %% [markdown]
# <a href="https://colab.research.google.com/github/KeerthanaKambham/Neural_Networks/blob/main/Tensorflow_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
x = tf.constant([0.0, 1.0, 50.0, 100.0])
tf.math.sigmoid(x)
# Out:
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([0.5      , 0.7310586, 1.       , 1.       ], dtype=float32)>

# %%
x = tf.constant([-100.0, -50.0, -1.0, 0.0])
tf.math.sigmoid(x)
# Out:
# <tf.Tensor: shape=(4,), dtype=float32, numpy=
# array([0.0000000e+00, 1.9287499e-22, 2.6894143e-01, 5.0000000e-01],
#       dtype=float32)>

# %%
import tensorflow as tf
x = tf.constant([-float("inf"), -5, -0.5, 1, 1.2, 2, 3, float("inf")])
tf.math.tanh(x)
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=
# array([-1.        , -0.99990916, -0.46211717,  0.7615942 ,  0.8336547 ,
#         0.9640276 ,  0.9950547 ,  1.        ], dtype=float32)>

# %%
t = tf.constant([[[1, 1, 1], [2, 2, 2]],
                 [[3, 3, 3], [4, 4, 4]],
                 [[5, 5, 5], [6, 6, 6]]])
tf.slice(t, [1, 0, 0], [1, 1, 3])  # [[[3, 3, 3]]]
tf.slice(t, [1, 0, 0], [1, 2, 3])  # [[[3, 3, 3],
                                   #   [4, 4, 4]]]
tf.slice(t, [1, 0, 0], [2, 1, 3])  # [[[3, 3, 3]],
                                   #  [[5, 5, 5]]]
# Out:
# <tf.Tensor: shape=(2, 1, 3), dtype=int32, numpy=
# array([[[3, 3, 3]],
#
#        [[5, 5, 5]]], dtype=int32)>
